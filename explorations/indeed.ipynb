# %%
from indeed import IndeedClient
client = IndeedClient(publisher = "7559832684683652")

import pprint

# %%
# API documentation: https://github.com/indeedlabs/indeed-python

params = {
    'q' : "email marketing",
    'l' : "10014",
    'userip' : "1.2.3.4",
    'useragent' : "Mozilla/5.0 (Macintosh; Intel Mac OS X 10_8_2)",
    'limt': 25
}

search_response = client.search(**params)
pprint.pprint(search_response)
# Out:
# {'dupefilter': True,
#  'end': 10,
#  'highlight': True,
#  'location': '10014',
#  'pageNumber': 0,
#  'paginationPayload': '',
#  'query': 'email marketing',
#  'radius': 25,
#  'results': [{'city': 'New York',
#               'company': 'Kate Spade & Company',
#               'country': 'US',
#               'date': 'Thu, 23 Mar 2017 00:54:56 GMT',
#               'expired': False,
#               'formattedLocation': 'New York, NY',
#               'formattedLocationFull': 'New York, NY',
#               'formattedRelativeTime': '2 days ago',
#               'indeedApply': False,
#               'jobkey': 'f1b685e6c5d2cd6e',
#               'jobtitle': 'Ecommerce Assistant - Email Marketing',
#               'onmousedown': "indeed_clk(this,'5115');",
#               'snippet': 'Kate Spade is looking for an experienced, '
#                          'goal-oriented, digital <b>marketing</b> professional '
# ...
