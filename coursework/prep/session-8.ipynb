# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
np.random.seed(111)
x = np.random.poisson(78, 1000)
plt.boxplot(x, showfliers=False)
plt.show()

# red line = median (central tendency)
# blue box = each edge is the median of medians for values from the red line out to the black line
# the black line is 

plt.boxplot(x)
plt.show()

# %%
plt.hist(x)
plt.axvline(np.median(x), color='r', linestyle='solid', linewidth=2)
plt.show()

# %%
# Monty hall
